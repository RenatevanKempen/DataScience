# %% [markdown]
# # Webscraping with Scrapy

# %% [markdown]
# There are many ways to perform webscraping.
#
# In this Jupyter notebook, I'll use only Scrapy to show what you can do.

# %%
import scrapy

# %%
#Let's import the selector function of Scrapy
from scrapy import Selector

# %%
# Import the CrawlerProcess to create a spider that goes over the page 
from scrapy.crawler import CrawlerProcess

# %%
#for this scrapy spider, I've chosen the courses page of DataCamp to be crawled through
url_short = 'https://www.datacamp.com/courses/all'

# %%
# Create the Spider class
class YourSpider(scrapy.Spider):
    name = 'yourspider'
    
    # start_requests method
    def start_requests( self ):
        yield scrapy.Request(url = url_short, callback = self.parse)
      
    def parse(self, response):
    #Now collect the titles and descriptions of the courses
        crs_titles = response.xpath('//h4[contains(@class,"course-block__title")]/text()').extract()
        crs_descrs = response.xpath('//p[contains(@class,"course-block__description")]/text()').extract()
        for crs_title, crs_descr in zip(crs_titles, crs_descrs ):
            dc_dict[crs_title] = crs_descr
    
# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# Run the Spider
process = CrawlerProcess()
process.crawl(YourSpider)
process.start()
# Out:
# 2020-03-05 15:21:41 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: scrapybot)
# 2020-03-05 15:21:41 [scrapy.utils.log] INFO: Versions: lxml 4.3.2.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.7.0, Python 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.6.1, Platform Windows-10-10.0.18362-SP0
# 2020-03-05 15:21:41 [scrapy.crawler] INFO: Overridden settings: {}
# 2020-03-05 15:21:41 [scrapy.extensions.telnet] INFO: Telnet Password: 8898cf62d5fa4612
# 2020-03-05 15:21:41 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-03-05 15:21:42 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-03-05 15:21:42 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-03-05 15:21:42 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-03-05 15:21:42 [scrapy.core.engine] INFO: Spider opened
# 2020-03-05 15:21:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-03-05 15:21:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-03-05 15:21:45 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.datacamp.com/courses/all> (referer: None)
# 2020-03-05 15:21:46 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-03-05 15:21:46 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 226,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 987108,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 3.940141,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 3, 5, 14, 21, 46, 35940),
#  'log_count/DEBUG': 1,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 3, 5, 14, 21, 42, 95799)}
# 2020-03-05 15:21:46 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
dc_dict
# Out:
# {'Introduction to R': '\n          Master the basics of data analysis by manipulating common data structures such as vectors, matrices, and data frames.\n        ',
#  'Intermediate R': '\n          Continue your journey to becoming an R ninja by learning about conditional statements, loops, and vector functions.\n        ',
#  'Introduction to Machine Learning': '\n          Learn to train and assess models performing common machine learning tasks such as classification and clustering.\n        ',
#  'Cleaning Data in R': '\n          Learn to explore your data so you can properly clean and prepare it for analysis.\n        ',
#  'Introduction to Python': '\n          Master the basics of data analysis in Python. Expand your skillset by learning scientific computing with numpy.\n        ',
#  'Intermediate R: Practice': '\n          Strengthen your knowledge of the topics you learned in Intermediate R with a ton of new and fun exercises.\n        ',
#  'Data Visualization with ggplot2 (Part 1)': '\n          Learn to produce meaningful and beautiful data visualizations with ggplot2 by understanding the grammar of graphics.\n        ',
#  'Data Visualization with ggplot2 (Part 2)': '\n          Take your data visualization skills to the next level with coordinates, facets, themes, and best practices in ggplot2.\n        ',
#  'Intermediate Python': '\n          Level up your data science skills by creating visualizations using Matplotlib and manipulating DataFrames with pandas.\n        ',
#  'Data Visualization with ggplot2 (Part 3)': '\n          This course covers some advanced topics including strategies for handling large data sets and specialty plots.\n        ',
#  'Text Mining with Bag-of-Words in R': '\n          Learn the bag of words technique for text mining with R.\n        ',
#  'Case Study: Exploring Baseball Pitching Data in R': "\n          Use a rich baseball dataset from the MLB's Statcast system to practice your data exploration skills.\n        ",
#  'Introduction to Portfolio Analysis in R': '\n          Apply your finance and R skills to backtest, analyze, and optimize financial portfolios.\n        ',
#  'Credit Risk Modeling in R': '\n          Apply statistical modeling in a real-life setting using logistic regression and decision trees to model credit risk.\n        ',
#  'Machine Learning with caret in R': '\n          This course teaches the big ideas in machine learning like how to build and evaluate predictive models.\n        ',
#  'Introduction to Databases in Python': "\n          In this course, you'll learn the basics of relational databases and how to interact with them.\n        ",
#  'Manipulating Time Series Data with xts and zoo in R': '\n          The xts and zoo packages make the task of managing and manipulating ordered observations fast and mistake free.\n        ',
#  'Time Series Analysis in R': '\n          Learn the core techniques necessary to extract meaningful insights from time series data.\n        ',
#  'Importing & Cleaning Data in R: Case Studies': "\n          In this series of four case studies, you'll revisit key concepts from our courses on importing and cleaning data in R.\n        ",
#  'Financial Trading in R': '\n          This course covers the basics of financial trading and how to use quantstrat to build signal-based trading strategies.\n        ',
#  'Importing and Managing Financial Data in R': '\n          Learn how to access financial data from local files as well as from internet sources.\n        ',
#  'Interactive Data Visualization with Bokeh': '\n          Learn how to create versatile and interactive data visualizations using Bokeh.\n        ',
#  'Case Study: Exploratory Data Analysis in R': '\n          Use data manipulation and visualization skills to explore the historical voting of the United Nations General Assembly.\n        ',
#  'Introduction to Importing Data in R': '\n          In this course, you will learn to read CSV, XLS, and text files in R using tools like readxl and data.table.\n        ',
#  'Intermediate Importing Data in R': "\n          Parse data in any format. Whether it's flat files, statistical software, databases, or data right from the web.\n        ",
#  'Data Visualization in R': '\n          This course provides a comprehensive introduction to working with base graphics in R.\n        ',
#  'Python Data Science Toolbox (Part 2)': '\n          Continue to build your modern Data Science skills by learning about iterators and list comprehensions.\n        ',
#  'Python Data Science Toolbox (Part 1)': '\n          Learn the art of writing your own functions in Python, as well as key concepts like scoping and error handling.\n        ',
#  'Statistical Thinking in Python (Part 1)': '\n          Build the foundation you need to think statistically and to speak the language of your data.\n        ',
#  'Statistical Thinking in Python (Part 2)': '\n          Learn to perform the two key tasks in statistical inference: parameter estimation and hypothesis testing.\n        ',
#  'Introduction to Statistical Modeling in R': '\n          This course is designed to get you up to speed with the most important and powerful methodologies in statistics.\n        ',
#  'Intermediate Statistical Modeling in R': '\n          In this follow-up course, you will expand your stat modeling skills from the introduction and dive into more advanced...\n        ',
#  'Intermediate Portfolio Analysis in R': '\n          Advance you R finance skills to backtest, analyze, and optimize financial portfolios.\n        ',
#  'Intermediate Importing Data in Python': '\n          Improve your Python data importing skills and learn to work with web and API data.\n        ',
#  'Introduction to Importing Data in Python': '\n          Learn to import data into Python from various sources, such as Excel, SQL, SAS and right from the web.\n        ',
#  'pandas Foundations': '\n          Learn how to use the industry-standard pandas library to import, build, and manipulate DataFrames.\n        ',
#  'Manipulating DataFrames with pandas': '\n          You will learn how to tidy, rearrange, and restructure your data using versatile pandas DataFrames.\n        ',
#  'Merging DataFrames with pandas': "\n          This course is all about the act of combining, or merging, DataFrames, an essential part your Data Scientist's toolbox. \n        ",
#  'Bond Valuation and Analysis in R': '\n          Learn to use R to develop models to evaluate and analyze bonds as well as protect them from interest rate changes.\n        ',
#  'Foundations of Inference in R': '\n          Learn how to draw conclusions about a population from a sample of data via a process known as statistical inference.\n        ',
#  'Introduction to Data Visualization in Python': '\n          Learn complex data visualization techniques using Matplotlib and seaborn.\n        ',
#  'Exploratory Data Analysis in R': '\n          Learn how to use graphical and numerical techniques to begin uncovering the structure of your data.\n        ',
#  'Correlation and Regression in R': '\n          Learn how to describe relationships between two numerical quantities and characterize these relationships graphically.\n        ',
#  'Introduction to Data in R': '\n          Learn the language of data, study types,  sampling strategies, and experimental design.\n        ',
#  'ARIMA Models in R': '\n          Become an expert in fitting ARIMA (autoregressive integrated moving average) models to time series data using R.\n        ',
#  'Unsupervised Learning in R': '\n          This course provides an intro to clustering and dimensionality reduction in R from a machine learning perspective.\n        ',
#  'Visualizing Geospatial Data in R': '\n          Learn to read, explore, and manipulate spatial data then use your skills to create informative maps using R.\n        ',
#  'Introduction to Network Analysis in Python': '\n          This course will equip you with the skills to analyze, visualize, and make sense of networks using the NetworkX library.\n        ',
#  'Supervised Learning with scikit-learn': "\n          Learn how to build and tune predictive models and evaluate how well they'll perform on unseen data.\n        ",
#  'Introduction to SQL': '\n          Master the basics of querying tables in relational databases such as MySQL, SQL Server, and PostgreSQL.\n        ',
#  'Case Studies: Manipulating Time Series Data in R': '\n          Strengthen your knowledge of the topics covered in Manipulating Time Series in R using real case study data.\n        ',
#  'Introduction to Deep Learning in Python': '\n          Learn the fundamentals of neural networks and how to build deep learning models using Keras 2.0.\n        ',
#  'Object-Oriented Programming with S3 and R6 in R': '\n          Manage the complexity in your code using object-oriented programming with the S3 and R6 systems.\n        ',
#  'Sentiment Analysis in R': '\n          Learn sentiment analysis by identifying positive and negative language, specific emotional intent and making compelli...\n        ',
#  'Cleaning Data in Python': '\n          This course will equip you with all the skills you need to clean your data in Python.\n        ',
#  'Unsupervised Learning in Python': '\n          Learn how to cluster, transform, visualize, and extract insights from unlabeled datasets using scikit-learn and scipy.\n        ',
#  'Visualizing Time Series Data in R': '\n          Learn how to visualize time series in R, then practice with a stock-picking case study.\n        ',
#  'Life Insurance Products Valuation in R': '\n          Learn the basics of cash flow valuation, work with human mortality data and build life insurance products in R.\n        ',
#  'Foundations of Probability in R': "\n          In this course, you'll learn about the concepts of random variables, distributions, and conditioning.\n        ",
#  'Scalable Data Processing in R': '\n          Learn how to write scalable code for working with big data in R using the bigmemory and iotools packages.\n        ',
#  'Case Study: School Budgeting with Machine Learning i...': '\n          Learn how to build a model to automatically classify items in a school budget.\n        ',
#  'Introduction to R for Finance': '\n          Learn essential data structures such as lists and data frames and apply that knowledge directly to financial examples.\n        ',
#  'Intermediate R for Finance': '\n          Learn about how dates work in R, and explore the world of if statements, loops, and functions using financial examples.\n        ',
#  'Supervised Learning in R: Classification': '\n          In this course you will learn the basics of machine learning for classification.\n        ',
#  'String Manipulation with stringr in R': '\n          Learn how to pull character strings apart, put them back together and use the stringr package.\n        ',
#  'Writing Efficient R Code': '\n          Learn to write faster R code, discover benchmarking and profiling, and unlock the secrets of parallel programming.\n        ',
#  'Forecasting in R': '\n          Learn how to make predictions about the future using time series forecasting in R.\n        ',
#  'Machine Learning with Tree-Based Models in R': "\n          In this course, you'll learn how to use tree-based models and ensembles for regression and classification.\n        ",
#  'Working with Web Data in R': '\n          Learn how to efficiently import data from the web into R.\n        ',
#  'Quantitative Risk Management in R': '\n          Work with risk-factor return series, study their empirical properties, and make estimates of value-at-risk. \n        ',
#  'Spatial Statistics in R': '\n          Learn how to make sense of spatial data and deal with various classes of statistical problems associated with it.\n        ',
#  'Data Visualization with lattice in R': '\n          Learn to visualize multivariate datasets using lattice graphics.\n        ',
#  'Introduction to Spark with sparklyr in R': '\n          Learn how to analyze huge datasets using Apache Spark and R using the sparklyr package.\n        ',
#  'Data Types for Data Science in Python': '\n          Consolidate and extend your knowledge of Python data types such as lists, dictionaries, and tuples, leveraging them t...\n        ',
#  'Sentiment Analysis in R: The Tidy Way': '\n          In this course, you will the learn principles of sentiment analysis from a tidy data perspective.\n        ',
#  'Intermediate Network Analysis in Python': '\n          Analyze time series graphs, use bipartite graphs, and gain the skills to tackle advanced problems in network analytics.\n        ',
#  'Multiple and Logistic Regression in R': "\n          In this course you'll learn to add multiple variables to linear models and to use logistic regression for classificat...\n        ",
#  'Inference for Linear Regression in R': "\n          In this course you'll learn how to perform inference using linear models.\n        ",
#  'Introduction to Natural Language Processing in Python': '\n          Learn fundamental natural language processing techniques using Python and how to apply them to extract insights from ...\n        ',
#  'Building Chatbots in Python': '\n          Learn the fundamentals of how to build conversational bots using rule-based systems as well as machine learning.\n        ',
#  'Extreme Gradient Boosting with XGBoost': '\n          Learn the fundamentals of gradient boosting and build state-of-the-art machine learning models using XGBoost to solve...\n        ',
#  'Equity Valuation in R': '\n          Learn the fundamentals of valuing stocks. \n        ',
#  'Case Studies: Building Web Applications with Shiny in R': '\n          Practice your Shiny skills while building some fun Shiny apps for real-life scenarios!\n        ',
#  'Supervised Learning in R: Regression': '\n          In this course you will learn how to predict future events using linear regression, generalized additive models, rand...\n        ',
#  'Importing and Managing Financial Data in Python': "\n          In this course, you'll learn how to import and manage financial data in Python using various tools and sources.\n        ",
#  'Optimizing R Code with Rcpp': '\n          Use C++ to dramatically boost the performance of your R code.\n        ',
#  'Manipulating Time Series Data in Python': "\n          In this course you'll learn the basics of working with time series data.\n        ",
#  'Time Series Analysis in Python': "\n          In this course you'll learn the basics of analyzing time series data.\n        ",
#  'Parallel Programming with Dask in Python': '\n          Learn how to take the Python workflows you currently have and easily scale them up to large datasets without the need...\n        ',
#  'Spatial Analysis with sf and raster in R': '\n          Analyze spatial data using the sf and raster packages. \n        ',
#  'Introduction to PySpark': '\n          Learn to implement distributed data management and machine learning in\r\nSpark using the PySpark package.\n        ',
#  'Network Analysis in R': "\n          In this course you'll learn to analyze and visualize network data with the igraph package.\n        ",
#  'Case Studies in Statistical Thinking': '\n          Take vital steps towards mastery as you apply your statistical thinking skills to real-world data sets and extract ac...\n        ',
#  'Joining Data in SQL': '\n          Join two or three tables together into one, combine tables using set theory, and work with subqueries in PostgreSQL.\n        ',
#  'Introduction to the Tidyverse': '\n          Get started on the path to exploring and visualizing your own data with the tidyverse, a powerful and popular collect...\n        ',
#  'Introduction to Shell': '\n          The Unix command line helps users combine existing programs in new ways, automate repetitive tasks, and run programs ...\n        ',
#  'Developing R Packages': '\n          Create and share your own R Packages!\n        ',
#  'Inference for Numerical Data in R': "\n          In this course you'll learn techniques for performing statistical inference on numerical data.\n        ",
#  'Visualizing Time Series Data in Python': '\n          Visualize seasonality, trends and other patterns in your time series data. \n        ',
#  'Data Manipulation with data.table in R': '\n          Master core concepts about data manipulation such as filtering, selecting and calculating groupwise statistics using ...\n        ',
#  'Fundamentals of Bayesian Data Analysis in R': '\n          Learn what Bayesian data analysis is, how it works, and why it is a useful tool to have in your data science toolbox.\n        ',
#  'Working with Dates and Times in R': '\n          Learn the essentials of parsing, manipulating and computing with dates and times in R.\n        ',
#  'Introduction to Git': '\n          This course is an introduction to version control with Git for data scientists. \n        ',
#  'Python for R Users': '\n          This course is for R users who want to get up to speed with Python!\n        ',
#  'Cluster Analysis in R': '\n          Develop a strong intuition for how hierarchical and k-means clustering work and learn how to apply them to extract in...\n        ',
#  'Introduction to Financial Concepts in Python': '\n          Using Python and NumPy, learn the most fundamental financial concepts. \n        ',
#  'Introduction to Portfolio Risk Management in Python': '\n          Evaluate portfolio risk and returns, construct market-cap weighted equity portfolios and learn how to forecast and he...\n        ',
#  'Inference for Categorical Data in R': "\n          In this course you'll learn how to leverage statistical techniques for working with categorical data.\n        ",
#  'Conda Essentials': '\n          Learn how to easily manage your software using conda. \n        ',
#  'Interactive Data Visualization with plotly in R': '\n          Learn to create interactive graphics entirely in R with plotly.\n        ',
#  'Visualizing Big Data with Trelliscope in R': '\n          Learn how to visualize big data in R using ggplot2 and trelliscopejs.\n        ',
#  'Building Dashboards with flexdashboard': "\n          In this course you'll learn how to create static and interactive dashboards using flexdashboard and shiny.\n        ",
#  'Communicating with Data in the Tidyverse': '\n          Leverage the power of tidyverse tools to create publication-quality graphics and custom-styled reports that communica...\n        ',
#  'Introduction to Linear Modeling in Python': '\n          Explore the concepts and applications of linear models with python and build models to describe, predict, and extract...\n        ',
#  'Introduction to MongoDB in Python': '\n          Learn to manipulate and analyze flexibly structured data with MongoDB.\n        ',
#  'ChIP-seq with Bioconductor in R': '\n          Learn how to analyse and interpret ChIP-seq data with the help of Bioconductor using a human cancer dataset.\n        ',
#  'Joining Data with data.table in R': '\n          This course will show you how to combine and merge datasets with data.table.\n        ',
#  'Foundations of Functional Programming with purrr': '\n          Learn to easily summarize and manipulate lists using the purrr package.\n        ',
#  'Visualization Best Practices in R': '\n          Learn to  effectively convey your data with an overview of common charts, alternative visualization types, and percep...\n        ',
#  'Building Dashboards with shinydashboard': "\n          In this course you'll learn to build dashboards using the shinydashboard package.\n        ",
#  'Modeling with Data in the Tidyverse': '\n          Explore Linear Regression in a tidy framework. \n        ',
#  'Human Resources Analytics: Exploring Employee Data in R': '\n          Manipulate, visualize, and perform statistical tests on HR data. \n        ',
#  'Business Process Analytics in R': '\n          Learn how to analyze business processes in R and extract actionable insights from enormous sets of event data. \n        ',
#  'Working with Data in the Tidyverse': '\n          Learn to work with data using tools from the tidyverse, and master the important skills of taming and tidying your data.\n        ',
#  'Supervised Learning in R: Case Studies': '\n          Apply your supervised machine learning skills by working through four case studies using data from the real world.\n        ',
#  'Forecasting Product Demand in R': '\n          Learn how to identify important drivers of demand, look at seasonal effects, and predict demand for a hierarchy of pr...\n        ',
#  'Machine Learning for Marketing Analytics in R': "\n          In this course you'll learn how to use data science for several common marketing tasks.\n        ",
#  'Case Studies: Network Analysis in R': '\n          Apply fundamental concepts in network analysis to large real-world datasets in 4 different case studies.\n        ',
#  'Hierarchical and Mixed Effects Models in R': '\n          In this course you will learn to fit hierarchical models with random effects.\n        ',
#  'Machine Learning for Time Series Data in Python': '\n          This course focuses on feature engineering and machine learning for time series data. \n        ',
#  'Customer Analytics and A/B Testing in Python': '\n          Learn how to use Python to create, run, and analyze A/B tests to make proactive business decisions.\n        ',
#  'Linear Classifiers in Python': '\n          In this course you will learn the details of linear classifiers like logistic regression and SVM.\n        ',
#  'Human Resources Analytics: Predicting Employee Churn...': '\n          Predict employee turnover and design retention strategies. \n        ',
#  'Parallel Programming in R': '\n          This course covers in detail the tools available in R for parallel computing.\n        ',
#  'Feature Engineering with PySpark': '\n          Learn the gritty details that data scientists are spending 70-80% of their time on; data wrangling and feature engine...\n        ',
#  'Machine Learning with Tree-Based Models in Python': "\n          In this course, you'll learn how to use tree-based models and ensembles for regression and classification using sciki...\n        ",
#  'Introduction to Bioconductor in R': '\n          Learn to use essential bioconductor packages using datasets from virus, fungus, human and plants!\n        ',
#  'Marketing Analytics: Predicting Customer Churn in Py...': '\n          Learn how to use Python to analyze customer churn and build a model to predict it.\n        ',
#  'Data Privacy and Anonymization in R': '\n          Publicly release data sets with a differential privacy guarantee. \n        ',
#  'Nonlinear Modeling in R with GAMs': '\n          GAMs model relationships in data as nonlinear functions that are highly adaptable to different types of data science ...\n        ',
#  'Bayesian Modeling with RJAGS': "\n          In this course, you'll learn how to implement more advanced Bayesian models using RJAGS.\n        ",
#  'Structural Equation Modeling with lavaan in R': '\n          Learn how to create and assess measurement models used to confirm the structure of a scale or questionnaire.\n        ',
#  'Differential Expression Analysis with limma in R': '\n          Learn to use the Bioconductor package limma for differential gene expression analysis.\n        ',
#  'Factor Analysis in R': '\n          Explore latent variables, such as personality using exploratory and confirmatory factor analyses.\n        ',
#  'Introduction to Predictive Analytics in Python': "\n          In this course you'll learn to use and present logistic regression models for making predictions.\n        ",
#  'Choice Modeling for Marketing in R': '\n          Learn to analyze and model customer choice data in R.\n        ',
#  'Categorical Data in the Tidyverse': '\n          Get ready to categorize! In this course,  you will work with non-numerical data, such as job titles or survey respons...\n        ',
#  'Multivariate Probability Distributions in R': '\n          Learn to analyze, plot, and model multivariate data.\n        ',
#  'Advanced Deep Learning with Keras': '\n          Build multiple-input and multiple-output deep learning models using Keras.\n        ',
#  'Experimental Design in R': "\n          In this course you'll learn about basic experimental design, a crucial part of any data analysis.\n        ",
#  'Preprocessing for Machine Learning in Python': "\n          In this course you'll learn how to get your cleaned data ready for modeling.\n        ",
#  'Machine Learning for Finance in Python': '\n          Learn to model and predict stock data values using linear models, decision trees, random forests, and neural networks.\n        ',
#  'Building Response Models in R': '\n          Learn to build simple models of market response to increase the effectiveness of your marketing plans.\n        ',
#  'Bayesian Regression Modeling with rstanarm': '\n          Learn how to leverage Bayesian estimation methods to make better inferences about linear regression models.\n        ',
#  'Intermediate Functional Programming with purrr': '\n          Continue learning with purrr to create robust, clean, and easy to maintain iterative code.\n        ',
#  'Introduction to Python for Finance': '\n          This course introduces Python for financial analysis.\n        ',
#  'Analyzing Survey Data in R': '\n          Learn survey design using common design structures followed by visualizing and analyzing survey results.\n        ',
#  'Mixture Models in R': '\n          Learn mixture models: a convenient and formal statistical framework for probabilistic clustering and classification.\n        ',
#  'Network Analysis in the Tidyverse': '\n          Learn how to analyze and visualize network data in the R programming language using the tidyverse approach.\n        ',
#  'Hyperparameter Tuning in R': "\n          Learn how to tune your model's hyperparameters to get the best predictive results.\n        ",
#  'Support Vector Machines in R': '\n          This course will introduce the support vector machine (SVM) using an intuitive, visual approach.\n        ',
#  'Interactive Maps with leaflet in R': '\n          Learn how to produce interactive web maps with ease using leaflet.\n        ',
#  'Analyzing Election and Polling Data in R': '\n          Learn R for data science by wrangling, visualizing, and modeling political data like polls and election results.\n        ',
#  'A/B Testing in R': '\n          Learn A/B testing: including hypothesis testing, experimental design, and confounding variables.\n        ',
#  'RNA-Seq with Bioconductor in R': '\n          Use RNA-Seq differential expression analysis to identify genes likely to be important for different diseases or condi...\n        ',
#  'Analyzing Police Activity with pandas': '\n          Explore the Stanford Open Policing Project dataset and analyze the impact of gender on police behavior using pandas.\n        ',
#  'Analyzing US Census Data in R': '\n          Learn to rapidly visualize and explore demographic data from the United States Census Bureau using tidyverse tools.\n        ',
#  'Building and Distributing Packages with Conda': '\n          Learn how to write Conda recipes and share them on Anaconda Cloud. \n        ',
#  'Intermediate Data Visualization with Seaborn': "\n          Use Seaborn's sophisticated visualization tools to make beautiful, informative visualizations with ease.\n        ",
#  'Anomaly Detection in R': '\n          Learn statistical tests for identifying outliers and how to use sophisticated anomaly scoring algorithms. \n        ',
#  'Statistical Simulation in Python': '\n          Learn to solve increasingly complex problems using simulations to generate and analyze data.\n        ',
#  'Financial Forecasting in Python': '\n          Step into the role of CFO and learn how to advise a board of directors on key metrics while building a financial fore...\n        ',
#  'Dealing With Missing Data in R': '\n          Make it easy to visualise, explore, and impute missing data with naniar, a tidyverse friendly approach to missing data.\n        ',
#  'Python for MATLAB Users': '\n          Transition from MATLAB by learning some fundamental Python concepts, and diving into the NumPy and Matplotlib packages.\n        ',
#  'Visualizing Geospatial Data in Python': '\n          Learn how to make attractive visualizations of geospatial data in Python using the geopandas package and folium maps.\n        ',
#  'Survival Analysis in R': '\n          Learn to work with time-to-event data. The event may be death or finding a job after unemployment. Learn to estimate,...\n        ',
#  'Biomedical Image Analysis in Python': '\n          Learn the fundamentals of exploring, manipulating, and measuring biomedical image data. \n        ',
#  'Building Recommendation Engines with PySpark': '\n          Learn tools and techniques to leverage your own big data to facilitate positive experiences for your users.\n        ',
#  'Financial Analytics in R': '\n          Learn how to speak the language (and do the math!) of corporate finance to pitch your next great business idea.\n        ',
#  'Interactive Data Visualization with rbokeh': '\n          Learn rbokeh: a visualization library for interactive web-based plots.\n        ',
#  'Intermediate Interactive Data Visualization with plo...': '\n          Learn to create animated graphics and linked views entirely in R with plotly.\r\n\r\n\n        ',
#  'Machine Learning in the Tidyverse': '\n          Leverage the tools in the tidyverse to generate, explore and evaluate machine learning models.\n        ',
#  'Predictive Analytics using Networked Data in R': '\n          Learn to predict labels of nodes in networks using network learning and by extracting descriptive features from the n...\n        ',
#  'Pivot Tables in Spreadsheets': '\n          Explore the world of Pivot Tables within Google Sheets, and learn how to quickly organize thousands of data points wi...\n        ',
#  'Intermediate SQL Server': "\n          In this course, you will use T-SQL, the flavor of SQL used in Microsoft's SQL Server for data analysis.\n        ",
#  'Web Scraping in Python': '\n          Learn to retrieve and parse information from the internet using the Python library scrapy.\n        ',
#  'Working with Geospatial Data in Python': '\n          This course will show you how to integrate spatial data into your Python Data Science workflow. \n        ',
#  'Designing and Analyzing Clinical Trials in R': '\n          In this course you will gain an overview clinical trial designs, determine the numbers of patients needed and conduct...\n        ',
#  'Single-Cell RNA-Seq with Bioconductor in R': '\n          Analyze single-cell RNA-Seq data  using normalization, dimensionality reduction, clustering and differential expression.\n        ',
#  'Intermediate Spreadsheets': '\n          Expand your spreadsheets vocabulary by diving deeper into data types, including numeric data, logical data, and missi...\n        ',
#  'Image Processing with Keras in Python': '\n          Learn powerful techniques for image analysis in Python using deep learning and convolutional neural networks in Keras.\n        ',
#  'Linear Algebra for Data Science in R': '\n          This course is an introduction to linear algebra, one of the most important mathematical topics underpinning data sci...\n        ',
#  'Generalized Linear Models in R': '\n          The Generalized Linear Model course expands your regression toolbox to include logistic and Poisson regression.\n        ',
#  'Writing Functions and Stored Procedures in SQL Server': '\n          Master SQL Server programming by learning to create, update, and execute functions and stored procedures.\n        ',
#  'Advanced NLP with spaCy': '\n          Learn how to use spaCy to build advanced natural language understanding systems, using both rule-based and machine le...\n        ',
#  'Introduction to Spreadsheets': '\n          Learn the basics of spreadsheets by working with rows, columns, addresses, and ranges. \n        ',
#  'Data Analysis in Spreadsheets': '\n          Learn how to analyze data with spreadsheets using functions such as SUM(), AVERAGE(), and VLOOKUP().\n        ',
#  'Supply Chain Analytics in Python': '\n          Leverage the power of Python and PuLP to optimize supply chains.\n        ',
#  'Fraud Detection in R': '\n          Learn to  detect fraud with analytics in R.\n        ',
#  'Analyzing Social Media Data in Python': "\n          In this course, you'll learn how to collect Twitter data and analyze Twitter text, networks, and geographical origin.\n        ",
#  'GARCH Models in R': '\n          Specify and fit GARCH models to forecast time-varying volatility and value-at-risk.\n        ',
#  'Course Creation at DataCamp': '\n          Learn all about how DataCamp builds the best platform to learn and teach data skills.\n        ',
#  'Longitudinal Analysis in R': '\n          Learn how to analyze and model longitudinal data. \n        ',
#  'Object-Oriented Programming in Python': '\n          Learn the fundamentals of object-oriented programming: classes, objects, methods, inheritance, polymorphism, and others!\n        ',
#  'Fraud Detection in Python': '\n          Learn how to detect fraud using Python.\n        ',
#  'Data Visualization in Spreadsheets': '\n          Learn the fundamentals of data visualization using spreadsheets. \n        ',
#  'Advanced Dimensionality Reduction in R': '\n          Learn how to apply advanced dimensionality techniques such as t-SNE and GLRM.\n        ',
#  'Customer Segmentation in Python': '\n          Learn how to segment customers in Python.\n        ',
#  'Topic Modeling in R': '\n          Learn how to fit topic models using the Latent Dirichlet Allocation algorithm.\n        ',
#  'Probability Puzzles in R': '\n          Learn strategies for answering probability questions in R by solving a variety of probability puzzles.\n        ',
#  'Feature Engineering in R': '\n          Learn a variety of feature engineering techniques to develop meaningful features that will uncover useful insights ab...\n        ',
#  'Defensive R Programming': '\n          Learn defensive programming in R to make your code more robust.\n        ',
#  'R For SAS Users': '\n          Learn how to translate your SAS knowledge into R and analyze data using this free and powerful software language.\n        ',
#  'Intermediate Predictive Analytics in Python': '\n          Learn how to prepare and organize your data for predictive analytics.\n        ',
#  'Analyzing US Census Data in Python': '\n          Learn to use the Census API to work with demographic and socioeconomic data.\n        ',
#  'Big Data Fundamentals with PySpark': '\n          Learn the fundamentals of working with big data with PySpark.\n        ',
#  'Dimensionality Reduction in Python': '\n          Learn to reduce dimensionality in Python.\n        ',
#  'Working with Dates and Times in Python': '\n          Learn how to work with dates and times in Python.\n        ',
#  'Designing Machine Learning Workflows in Python': '\n          Learn to build pipelines that stand the test of time.\n        ',
#  'Software Engineering for Data Scientists in Python': '\n          Learn all about modularity, documentation, &amp; automated testing to help you solve Data Science problems quicker an...\n        ',
#  'Exploratory Data Analysis in SQL': "\n          Learn how to explore what's available in a database: the tables, relationships between them, and data stored in them.\n        ",
#  'Intermediate SQL': '\n          Master the complex SQL queries necessary to answer a wide variety of data science questions and prepare robust data s...\n        ',
#  'Writing Efficient Python Code': '\n          Learn to write efficient code that executes quickly and allocates resources skillfully to avoid unnecessary overhead.\n        ',
#  'Introduction to Data Science in Python': '\n          Dive into data science using Python and learn how to effectively analyze and visualize your data.\n        ',
#  'Introduction to Relational Databases in SQL': '\n          Learn how to create one of the most efficient ways of storing data - relational databases! \n        ',
#  'Introduction to SQL Server': '\n          Become proficient at using SQL Server to perform common data manipulation tasks.\n        ',
#  'Introduction to Data Visualization with Matplotlib': '\n          Learn how to create, customize, and share data visualizations using Matplotlib.\n        ',
#  'Introduction to Text Analysis in R': '\n          Analyze text data in R using the tidy framework.\n        ',
#  'Feature Engineering for Machine Learning in Python': '\n          Create new features to improve the performance of your Machine Learning models. \n        ',
#  'Introduction to Statistics in Spreadsheets': '\n          Learn how to leverage statistical techniques using spreadsheets to more effectively work with and extract insights fr...\n        ',
#  'PostgreSQL Summary Stats and Window Functions': '\n          Learn how to create queries for analytics and data engineering with window functions, the SQL secret weapon! \n        ',
#  'Reporting in SQL': '\n          Learn how to build your very own dashboard by applying all the SQL concepts and functions you have learned in previou...\n        ',
#  'Foundations of Probability in Python': '\n          Learn fundamental probability concepts like random variables, mean and variance, probability distributions, and condi...\n        ',
#  'Writing Efficient Code with pandas': '\n          Learn efficient techniques in pandas to optimize your Python code.\n        ',
#  'Python for Spreadsheet Users': '\n          Use your knowledge of common spreadsheet functions and techniques to explore Python! \n        ',
#  'Improving Your Data Visualizations in Python': '\n          Learn to construct compelling and attractive visualizations that help communicate results efficiently and effectively.\n        ',
#  'Cluster Analysis in Python': '\n          In this course, you will be introduced to unsupervised learning through techniques such as hierarchical and k-means c...\n        ',
#  'AI Fundamentals': '\n          Learn the fundamentals of AI. No programming experience required!\n        ',
#  'Applying SQL to Real-World Problems': '\n          Find tables, store and manage new tables and views, and write maintainable SQL code to answer business questions.\n        ',
#  'Analyzing Marketing Campaigns with pandas': '\n          Build up your pandas skills and answer marketing questions by merging, slicing, visualizing, and more!\n        ',
#  'Financial Analytics in Spreadsheets': '\n          Learn how to build a graphical dashboard with spreadsheets to track the performance of financial securities.\n        ',
#  'Machine Learning with PySpark': '\n          Learn how to make predictions with Apache Spark.\n        ',
#  'Financial Modeling in Spreadsheets': '\n          Learn basic business modeling including cash flows, investments, annuities, loan amortization, and more using Sheets.\n        ',
#  'Introduction to Spark SQL in Python': '\n          Learn how to manipulate data and create machine learning feature sets in Spark using SQL in Python.\n        ',
#  'Conditional Formatting in Spreadsheets': '\n          Learn how to use conditional formatting with your data through built-in options and by creating custom formulas. \n        ',
#  'Introduction to TensorFlow in Python': '\n          Learn the fundamentals of neural networks and how to build deep learning models using TensorFlow.\n        ',
#  'Model Validation in Python': '\n          Learn the basics of model validation,  validation techniques, and begin creating validated and high performing models.\n        ',
#  'Hyperparameter Tuning in Python': '\n          Learn to tune hyperparameters in Python.\n        ',
#  'Introduction to Data Visualization with Seaborn': '\n          Learn how to create informative and attractive visualizations in Python using the Seaborn library.\n        ',
#  'Improving Query Performance in SQL Server': '\n          In this course, students will learn to write queries that are both efficient and easy to read and understand.\n        ',
#  'Analyzing Business Data in SQL': '\n          Learn to write SQL queries to calculate key metrics that businesses use to measure performance.\n        ',
#  'Ensemble Methods in Python': '\n          Learn how to build advanced and effective machine learning models in Python using ensemble techniques such as bagging...\n        ',
#  'Exploratory Data Analysis in Python': '\n          Learn how to explore, visualize, and extract insights from data. \n        ',
#  'Generalized Linear Models in Python': '\n          Extend your regression toolbox with the logistic and Poisson models and learn to train, understand, and validate them...\n        ',
#  'Data-Driven Decision Making in SQL': '\n          Learn how to analyze a SQL table and report insights to management.\n        ',
#  'Introduction to Deep Learning with PyTorch': '\n          Learn to create deep learning models with the PyTorch library.\n        ',
#  'Marketing Analytics in Spreadsheets': '\n          Learn how to ensure clean data entry and build dynamic dashboards to display your marketing data.\n        ',
#  'Writing Functions in Python': '\n          Learn to use best practices to write maintainable, reusable, complex functions with good documentation.\n        ',
#  'Data Processing in Shell': '\n          Learn powerful command-line skills to download, process,  and transform data, including machine learning pipeline.\n        ',
#  'Functions for Manipulating Data in SQL Server': '\n          Learn the most important functions for manipulating, processing, and transforming data in SQL Server.\n        ',
#  'Unit Testing for Data Science in Python': '\n          Learn how to write unit tests for your Data Science projects in Python using pytest.\n        ',
#  'Error and Uncertainty in Spreadsheets': '\n          Learn to distinguish real differences from random noise, and explore psychological crutches we use that interfere wit...\n        ',
#  'Analyzing IoT Data in Python': '\n          Learn how to import, clean and manipulate IoT data in Python to make it ready for machine learning.\n        ',
#  'Improving Query Performance in PostgreSQL': '\n          Learn how to structure your PostgreSQL queries to run in a fraction of the time.\n        ',
#  'Practicing Coding Interview Questions in Python': '\n          Prepare for your next coding interviews in Python.\n        ',
#  'Practicing Statistics Interview Questions in Python': '\n          Prepare for your next statistics interview by reviewing concepts like conditional probabilities, A/B testing, the bia...\n        ',
#  'Introduction to Deep Learning with Keras': '\n          Learn to start developing deep learning models with Keras.\n        ',
#  'Cleaning Data with PySpark': '\n          Learn how to clean data with Apache Spark in Python.\n        ',
#  'Experimental Design in Python': '\n          Learn about experimental design, and how to explore your data to ask and answer meaningful questions. \n        ',
#  'Feature Engineering for NLP in Python': '\n          Learn techniques to extract useful information from text and process them into a format suitable for machine learning.\n        ',
#  'Streamlined Data Ingestion with pandas': '\n          Learn to acquire data from common file formats and systems such as CSV files, spreadsheets, JSON, SQL databases, and ...\n        ',
#  'Building and Optimizing Triggers in SQL Server': '\n          Learn how to design and implement triggers in SQL Server using real-world examples.\n        ',
#  'Hierarchical and Recursive Queries in SQL Server': '\n          Learn how to write recursive queries and query hierarchical data structures.\n        ',
#  'Winning a Kaggle Competition in Python': '\n          Learn how to approach and win competitions on Kaggle.\n        ',
#  'Sentiment Analysis in Python': '\n          Are customers thrilled with your products or is your service lacking? Learn how to perform an end-to-end sentiment an...\n        ',
#  'Image Processing in Python': '\n          Learn to process, transform, and manipulate images at your will.\n        ',
#  'Functions for Manipulating Data in PostgreSQL': '\n          Learn the most important PostgreSQL functions for manipulating, processing, and transforming data. \n        ',
#  'Time Series Analysis in SQL Server': '\n          Explore ways to work with date and time data in SQL Server for time series analysis\n        ',
#  'Survey and Measurement Development in R': '\n          Design surveys to get actionable insights via reviewing of survey design structures and visualizing and analyzing sur...\n        ',
#  'Regular Expressions in Python': '\n          Learn about string manipulation and become a master at using regular expressions.\n        ',
#  'ARIMA Models in Python': '\n          Learn about ARIMA models in Python and become an expert in time series analysis.\n        ',
#  'Dealing with Missing Data in Python': '\n          Learn how to identify, analyze, remove and impute missing data in Python. \n        ',
#  'Recurrent Neural Networks for Language Modeling in P...': '\n          Use RNNs to classify text sentiment, generate sentences, and translate text between languages.\n        ',
#  'Introduction to AWS Boto in Python': '\n          Learn about AWS Boto and harnessing cloud technology to optimize your data workflow. \n        ',
#  'Data Science for Business': '\n          Learn about data science and how can you use it to strengthen your organization. \n        ',
#  'Machine Translation in Python': '\n          Are you curious about the inner workings of the models that are behind products like Google Translate? \n        ',
#  'Spoken Language Processing in Python': '\n          Learn to load, transform, and transcribe human speech from raw audio files in Python.\n        ',
#  'Building Data Engineering Pipelines in Python': '\n          Learn how to build data engineering pipelines in Python.\n        ',
#  'Introduction to Portfolio Analysis in Python': '\n          Learn how to calculate meaningful measures of risk and performance, and how to compile an optimal portfolio for the d...\n        ',
#  'Practicing Machine Learning Interview Questions in R': '\n          Prepare for your upcoming machine learning interview by working through these practice questions that span across imp...\n        ',
#  'Transactions and Error Handling in SQL Server': '\n          Learn to write scripts that will catch and handle errors and control for multiple operations happening at once.\n        ',
#  'Credit Risk Modeling in Python': '\n          Learn how to prepare credit application data, apply machine learning and business rules to reduce risk and ensure pro...\n        ',
#  'Introduction to TensorFlow in R': '\n          Learn how to use TensorFlow, a state-of-the-art machine learning framework that specializes in the ability to develop...\n        ',
#  'Introduction to Natural Language Processing in R': '\n          Gain an overview of all the skills and tools needed to excel in Natural Language Processing in R.\n        ',
#  'Machine Learning for Marketing in Python': '\n          From customer lifetime value, predicting churn to segmentation - learn and implement Machine Learning use cases for M...\n        ',
#  'Practicing Machine Learning Interview Questions in P...': '\n          Sharpen your knowledge in machine learning, and prepare for any potential question you might get in a machine learnin...\n        ',
#  'Data Manipulation with dplyr ': '\n          Learn to transform and manipulate your data using dplyr. \n        ',
#  'Introduction to Data Engineering': '\n          Learn about the world of data engineering with an overview of all its relevant topics and tools!\n        ',
#  'Pandas Joins for Spreadsheet Users': '\n          Learn how to effectively and efficiently join datasets in tabular format using the Python Pandas library.  \n        ',
#  'Introduction to Scala': '\n          Begin your journey with Scala, a popular language for scalable applications and data engineering infrastructure.\n        ',
#  'Introduction to Writing Functions in R': '\n          Take your R skills up a notch by learning to write efficient, reusable functions. \n        ',
#  'Analyzing Social Media Data in R': '\n          Extract and visualize Twitter data, perform sentiment and network analysis, and map the geolocation of your tweets.\n        ',
#  'Introduction to Data Visualization with ggplot2': '\n          Learn to produce meaningful and beautiful data visualizations with ggplot2 by understanding the grammar of graphics.\n        ',
#  'Creating PostgreSQL Databases': '\n          This course teaches you the skills and knowledge necessary to create and manage your own PostgreSQL databases.\n        ',
#  'Intermediate Data Visualization with ggplot2': '\n          Learn to use facets, coordinate systems and statistics in ggplot2 to create meaningful explanatory plots.\n        ',
#  'Practicing Statistics Interview Questions in R': "\n           In this course, you'll prepare for the most frequently covered statistical topics from distributions to hypothesis t...\n        ",
#  'Joining Data with dplyr': '\n          Learn to combine data across multiple tables to answer more complex questions with dplyr.\n        ',
#  'Predicting CTR with Machine Learning in Python': '\n          Learn how to predict click-through rates on ads and implement basic machine learning models in Python so that you can...\n        ',
#  'Database Design': '\n          Learn to design databases in SQL.\n        ',
#  'Intermediate Regular Expressions in R': '\n          Manipulate text data, analyze it and more by mastering regular expressions and string distances in R.\n        ',
#  'Introduction to Bash Scripting': '\n          Bash scripting allows you to build analytics pipelines in the cloud and work with data stored across multiple files.\n        ',
#  'Data Manipulation with pandas': '\n          Use the world’s most popular Python data science package to manipulate data and calculate summary statistics.\n        ',
#  'Data Science for Everyone': '\n          An introduction to data science with no coding involved.\n        ',
#  'Dimensionality Reduction in R': '\n          Develop your intuition for when to reduce dimensionality in your data, and master the fundamentals of how to do so in R.\n        ',
#  'Time Series with data.table in R': '\n          Master time series data using data.table in R. \n        ',
#  'Creating Robust Workflows in Python': '\n          Learn to develop a set of principles for your data science and software development projects.\n        ',
#  'Options Trading in Spreadsheets': '\n          Learn how to price options contracts and visualize payout of various options strategies using spreadsheets.\n        ',
#  'Loan Amortization in Spreadsheets': '\n          Learn how to build an amortization dashboard in spreadsheets with financial and conditional formulas.\n        ',
#  'Command Line Automation in Python': '\n          Learn to automate many common file system tasks and be able to manage and communicate with processes.\n        ',
#  'Market Basket Analysis in R': '\n          Explore association rules in market basket analysis with R by analyzing retail data and creating movie recommendations. \n        ',
#  'Building Web Applications with Shiny in R': '\n          Shiny is an R package that makes it easy to build interactive web apps directly in R, allowing your team to explore y...\n        ',
#  'Quantitative Risk Management in Python': '\n          Learn about risk management, value at risk and more applied to the 2008 financial crisis using Python. \n        ',
#  'Natural Language Generation in Python': '\n          Imitate Shakespear, translate language and autocomplete sentences using Deep Learning in Python.\n        ',
#  'Introduction to Oracle SQL': '\n          Learn how to import and manipulate data with Oracle SQL.\n        ',
#  'GARCH Models in Python': '\n          Learn about GARCH Models, how to implement them and calibrate them on financial data from stocks to foreign exchange.\n        ',
#  'Introduction to Tableau': '\n          Get started with Tableau, a widely used business intelligence (BI) and analytics software to explore, visualize, and ...\n        ',
#  'Machine Learning for Everyone': '\n          An introduction to machine learning with no coding involved.\n        '}

# %%
#Another way to get the same output is:

 Create the Spider class
class DC_Description_Spider(scrapy.Spider):
    name = "dc_chapter_spider"
    
  # start_requests method
    def start_requests(self):
        yield scrapy.Request(url = url_short,
                         callback = self.parse_front)
 
 # First parsing method
    def parse_front(self, response):
        course_blocks = response.css('div.course-block')
        course_links = course_blocks.xpath('./a/@href')
        links_to_follow = course_links.extract()
        for url in links_to_follow:
            yield response.follow(url = url,
                            callback = self.parse_pages)

 # Second parsing method
    def parse_pages(self, response):
    # Create a SelectorList of the course titles text
        crs_title = response.xpath('//h4[contains(@class,"course-block__title")]/text()')
    # Extract the text and strip it clean
        crs_title_ext = crs_title.extract_first().strip()
    # Create a SelectorList of course descriptions text
        crs_descr = response.css( 'p.course-block__description::text' )
    # Extract the text and strip it clean
        crs_descr_ext = crs_descr.extract_first().strip()
    # Fill in the dictionary
        dc_dict[crs_title_ext] = crs_descr_ext
    
# Initialize the dictionary **outside** of the Spider class
dc_dict = dict()

# Run the Spider
process = CrawlerProcess()
process.crawl(DC_Description_Spider)
process.start()
